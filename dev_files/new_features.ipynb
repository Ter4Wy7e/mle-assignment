# %%
import polars as pl
import pandas as pd

# %%
feature_filepath = "/app/datamart/gold/feature/gold_feature_2024-12-01.parquet"
label_filepath = "/app/datamart/gold/label/gold_label_2024-12-01_30dpd_6mob.parquet"
df_feature = pl.read_parquet(feature_filepath, use_pyarrow=True)
df_label = pl.read_parquet(label_filepath, use_pyarrow=True)
df_merged = df_feature.join(df_label, on=["customer_id", "snapshot_date"], how="left")
df_merged.sample(10)
# Out:
# shape: (10, 37)
# ┌─────────────┬──────────────┬─────┬──────────────┬───┬─────────┬──────────────┬───────┬───────────┐
# │ customer_id ┆ snapshot_dat ┆ age ┆ occupation   ┆ … ┆ loan_id ┆ loan_start_d ┆ label ┆ label_def │
# │ ---         ┆ e            ┆ --- ┆ ---          ┆   ┆ ---     ┆ ate          ┆ ---   ┆ ---       │
# │ str         ┆ ---          ┆ i32 ┆ str          ┆   ┆ str     ┆ ---          ┆ i32   ┆ str       │
# │             ┆ date         ┆     ┆              ┆   ┆         ┆ date         ┆       ┆           │
# ╞═════════════╪══════════════╪═════╪══════════════╪═══╪═════════╪══════════════╪═══════╪═══════════╡
# │ CUS_0xb460  ┆ 2023-12-01   ┆ 29  ┆ Doctor       ┆ … ┆ null    ┆ null         ┆ null  ┆ null      │
# │ CUS_0x96e5  ┆ 2024-07-01   ┆ 23  ┆ Developer    ┆ … ┆ null    ┆ null         ┆ null  ┆ null      │
# │ CUS_0x696c  ┆ 2023-10-01   ┆ 32  ┆ Manager      ┆ … ┆ null    ┆ null         ┆ null  ┆ null      │
# ...

# %%
df_feature.select('monthly_inhand_salary', 'total_emi_per_month').sample(5)
# Out:
# shape: (5, 2)
# ┌───────────────────────┬─────────────────────┐
# │ monthly_inhand_salary ┆ total_emi_per_month │
# │ ---                   ┆ ---                 │
# │ f32                   ┆ f32                 │
# ╞═══════════════════════╪═════════════════════╡
# │ 1671.352539           ┆ 31.746901           │
# │ 1300.897461           ┆ 58.119995           │
# │ 14615.236328          ┆ 455.598419          │
# │ 2847.000732           ┆ 66.676414           │
# │ 1474.859863           ┆ 131.547089          │
# └───────────────────────┴─────────────────────┘

# %%
df = df.with_columns(repayment_ability = pl.col('monthly_inhand_salary') - pl.col('total_emi_per_month'))

# %%
df.select(pl.col("repayment_ability").null_count())
# Out:
# shape: (1, 1)
# ┌───────────────────┐
# │ repayment_ability │
# │ ---               │
# │ u32               │
# ╞═══════════════════╡
# │ 0                 │
# └───────────────────┘

# %%
pl.read_parquet("/app/datamart/gold/train_view/gold_train_2023-09-01_beforeNormalisation.parquet", use_pyarrow=True)
# Out:
# shape: (741, 38)
# ┌─────────────┬─────────────┬──────┬────────────┬───┬────────────┬───────┬────────────┬────────────┐
# │ customer_id ┆ loan_start_ ┆ age  ┆ occupation ┆ … ┆ loan_id    ┆ label ┆ label_def  ┆ label_snap │
# │ ---         ┆ date        ┆ ---  ┆ ---        ┆   ┆ ---        ┆ ---   ┆ ---        ┆ shot_date  │
# │ str         ┆ ---         ┆ f64  ┆ str        ┆   ┆ str        ┆ i64   ┆ str        ┆ ---        │
# │             ┆ date        ┆      ┆            ┆   ┆            ┆       ┆            ┆ date       │
# ╞═════════════╪═════════════╪══════╪════════════╪═══╪════════════╪═══════╪════════════╪════════════╡
# │ CUS_0xd6f   ┆ 2023-01-01  ┆ 40.0 ┆ Mechanic   ┆ … ┆ CUS_0xd6f_ ┆ 0     ┆ 30dpd_6mob ┆ 2023-07-01 │
# │             ┆             ┆      ┆            ┆   ┆ 2023_01_01 ┆       ┆            ┆            │
# │ CUS_0x96a2  ┆ 2023-01-01  ┆ 30.0 ┆ Unknown    ┆ … ┆ CUS_0x96a2 ┆ 0     ┆ 30dpd_6mob ┆ 2023-07-01 │
# ...

# %%
df = pl.read_parquet("/app/123train.parquet", use_pyarrow=True)

# %%
df.columns
# Out:
# shape: (1_537, 32)
# ┌─────┬────────────┬────────────┬────────────┬───┬────────────┬────────────┬───────────┬───────────┐
# │ age ┆ occupation ┆ annual_inc ┆ monthly_in ┆ … ┆ type_of_lo ┆ investment ┆ income_pe ┆ repayment │
# │ --- ┆ ---        ┆ ome        ┆ hand_salar ┆   ┆ an_auto_lo ┆ _income_ra ┆ r_card    ┆ _ability  │
# │ i32 ┆ str        ┆ ---        ┆ y          ┆   ┆ an         ┆ tio        ┆ ---       ┆ ---       │
# │     ┆            ┆ f32        ┆ ---        ┆   ┆ ---        ┆ ---        ┆ f64       ┆ f32       │
# │     ┆            ┆            ┆ f32        ┆   ┆ i32        ┆ f64        ┆           ┆           │
# ╞═════╪════════════╪════════════╪════════════╪═══╪════════════╪════════════╪═══════════╪═══════════╡
# │ 45  ┆ Accountant ┆ 15989.0849 ┆ 1086.42370 ┆ … ┆ 1          ┆ 0.074064   ┆ 271.60592 ┆ 1052.6267 │
# │     ┆            ┆ 61         ┆ 6          ┆   ┆            ┆            ┆ 7         ┆ 09        │
# ...

# %%
df.columns
# Out:
# ['age',
#  'occupation',
#  'annual_income',
#  'monthly_inhand_salary',
#  'num_bank_accounts',
#  'num_credit_card',
#  'interest_rate',
#  'num_of_loan',
#  'delay_from_due_date',
#  'num_of_delayed_payment',
#  'changed_credit_limit',
#  'num_credit_inquiries',
#  'credit_mix',
#  'outstanding_debt',
#  'credit_utilization_ratio',
#  'credit_history_age',
#  'payment_of_min_amount',
#  'total_emi_per_month',
#  'amount_invested_monthly',
#  'payment_behaviour',
#  'monthly_balance',
#  'type_of_loan_payday_loan',
#  'type_of_loan_personal_loan',
#  'type_of_loan_home_equity_loan',
#  'type_of_loan_credit-builder_loan',
#  'type_of_loan_mortgage_loan',
#  'type_of_loan_student_loan',
#  'type_of_loan_debt_consolidation_loan',
#  'type_of_loan_auto_loan',
#  'investment_income_ratio',
#  'income_per_card',
#  'repayment_ability']
